# %%
#version 2.2
import requests
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)

urls = ["https://leomoon173.pixnet.net/blog/post/6777691", 
        "https://leomoon173.pixnet.net/blog/post/27331605", 
        "https://leomoon173.pixnet.net/blog/post/6777767", 
        "https://leomoon173.pixnet.net/blog/post/6777940", 
        "https://leomoon173.pixnet.net/blog/post/6777982"]

name_list = []; ingredient_list = []; kitchen_list = []; price_list = []
for url in urls:
    html = requests.get(url)
    html.encoding = "utf-8"
    sp = BeautifulSoup(html.text, 'lxml')

    infos = sp.find_all('td')
    info_list = []
    for info in infos:
        temp = info.text.strip('\n')
        name = ""
        for i in range(len(temp)):
            if(temp[i] == '\n' or temp[i] == '('):
                break
            name += temp[i]
        info_list.append(name)
        
    for i in range(len(info_list)):
        if(i % 4 == 0):
            name_list.append(info_list[i])
            continue
        elif(i % 4 == 1):
            ingredient_list.append(info_list[i])
            continue
        elif(i % 4 == 2):
            kitchen_list.append(info_list[i])
            continue
        elif(i % 4 == 3):
            price_list.append(info_list[i].replace('5☆ ', '').replace(' G', ''))
            continue
            
for i in range(len(ingredient_list)):
    temp_list = []
    ingredient_list[i] = ingredient_list[i].replace(' + ', ',')
    temp_list = ingredient_list[i].split(',')
    ingredient_list[i] = temp_list

for name in name_list:
    if(name == "名稱"):
        name_list.remove(name)
        
for ingredient in ingredient_list:
    if(ingredient[0] == "材料"):
        ingredient_list.remove(ingredient)
        
for kitchen in kitchen_list:
    if(kitchen == "廚具"):
        kitchen_list.remove(kitchen)
        
for price in price_list:
    if(price == "市集賣價"):
        price_list.remove(price)
    
search = input('請輸入食材：')
output = pd.DataFrame(columns = ["名稱", "材料", "廚具", "市集賣價"])
search_list = search.split(' ')

if(search != "index"):
    for i in range(len(ingredient_list)):
        for j in range(len(search_list)):
            if(search_list[j] in ingredient_list[i]):
                if(j == len(search_list) - 1):
                    output.loc[len(output)] = [name_list[i], ingredient_list[i], kitchen_list[i], price_list[i]]
                    break
                else:
                    continue
            else:
                break            
else:
    for i in range(len(ingredient_list)):
        output.loc[len(output)] = [name_list[i], ingredient_list[i], kitchen_list[i], price_list[i]]
        
output.市集賣價 = output.市集賣價.astype(int)
output.sort_values(by = "市集賣價", inplace = True, ascending = False)
output.index = [i + 1 for i in range(len(output))]
display(output)
# Out:
# 請輸入食材：index
#           名稱                             材料   廚具    市集賣價
# 1      杯裝四季酒                        [四季葡萄酒]  調味料  124320
# 2       王様奶茶         [黃金礦石頭混合茶, 新澤西牛奶/奇跡牛奶]  調味料   35840
# 3    黃金礦石混合茶                     [黃金礦石罐裝紅茶]  調味料   33770
# 4      杯裝春風酒                        [春風葡萄酒]   鍋子   29830
# 5       至高咖喱              [彩虹咖喱, 牛奶咖喱, 失敗作]  調味料   22400
# 6      杯裝夏風酒                        [夏風葡萄酒]   鍋子   19750
# 7      杯裝秋風酒                        [秋風葡萄酒]   鍋子   18590
# 8       究極咖喱              [彩虹咖喱, 海苔咖喱, 失敗作]  調味料   11200
# 9        鳳梨茶                       [罐裝鳳梨紅茶]   鍋子    9400
# 10     春色混合茶                       [春色罐裝紅茶]   鍋子    7430
# 11      彩虹咖喱       [咖喱飯, 菠菜, 蕃茄, 海苔, 新澤西牛奶]  調味料    6720
# 12     杯裝鳳梨酒                          [鳳梨酒]    -    5720
# 13     杯裝蜂蜜酒                          [蜂蜜酒]    -    3980
# 14     夏色混合茶                       [夏色罐裝紅茶]   鍋子    3670
# 15     杯裝漿果酒                          [藍莓酒]    -    3620
# 16     杯裝香蕉酒                          [香蕉酒]    -    3620
# 17     杯裝栗子酒                          [栗子酒]    -    3620
# 18     杯裝桃子酒                          [蜜桃酒]    -    3310
# 19    奶酪生日蛋糕                   [生日蛋糕, 上等奶酪]  調味料    3130
# 20     秋色混合茶                       [秋色罐裝紅茶]   鍋子    3000
# 21     杯裝橘子酒                          [橘子酒]    -    3000
# 22       藍莓茶                       [罐裝藍莓紅茶]   鍋子    2950
# 23       香蕉茶                       [罐裝香蕉紅茶]   鍋子    2950
# 24        抹茶                         [罐裝抹茶]    -    2950
# 25       烏龍茶                        [罐裝烏龍茶]    -    2950
# 26       八寶菜              [油, 包心菜, 胡蘿蔔, 香菇]   煎鍋    2910
# 27      義式麵湯              [義大利麵, 馬賽魚湯/黃油濃湯]   鍋子    2910
# 28     杯裝蘋果酒                          [蘋果酒]    -    2720
# 29    法式鹹奶油派              [小麥粉, 南瓜, 菠菜, 土豆]   煎鍋    2680
# 30   巧克力生日蛋糕                    [巧克力, 生日蛋糕]  調味料    2680
# 31       桃子茶                       [罐裝蜜桃紅茶]   鍋子    2680
# 32      白葡萄茶                      [罐裝白葡萄紅茶]   鍋子    2500
# 33       橘子茶                       [罐裝橘子紅茶]   鍋子    2410
# 34      紫葡萄茶                      [罐裝紫葡萄紅茶]   鍋子    2410
# 35   杯裝混合葡萄酒                        [混合葡萄酒]    -    2410
# 36       蘋果茶                       [罐裝蘋果紅茶]   鍋子    2280
# 37      生日蛋糕               [小麥粉, 上等黃油, 烏雞蛋]   煎鍋    2240
# 38    天婦羅烏冬麵                     [烏冬麵+ 天婦羅]   鍋子    2240
# 39    天婦羅蕎麥麵                     [蕎麥麵, 天婦羅]   鍋子    2240
# 40     杯裝櫻桃酒                          [櫻桃酒]    -    2240
# 41        春捲                  [米粉, 包心菜, 香菇]   鍋子    2240
# 42      黃油濃湯                   [土豆, 洋蔥, 黃油]   鍋子    2120
# 43      雜菜煎餅                  [小麥粉, 包心菜, 油]   煎鍋    2120
# 44     杯裝草莓酒                          [草莓酒]    -    2100
# 45     杯裝香檳酒                           [香檳]    -    2100
# 46      農夫早餐               [洋蔥, 土豆, 奶酪, 黃油]   鍋子    2100
# 47     杯裝番茄酒                          [番茄酒]    -    2100
# 48     杯裝玉米酒                          [玉米酒]    -    2100
# 49      燙包心菜                          [包心菜]   鍋子    2010
# 50      奶汁烤菜              [義大利通心麵, 洋蔥, 奶酪類]   鍋子    2010
# 51       炒菜花                        [菜花, 油]    -    2010
# 52       小甜餅             [小麥粉, 上等黃油, 新澤西牛奶]    -    1990
# 53      天婦羅丼                      [米飯, 天婦羅]    -    1990
# 54       壽司飯         [米飯, 生魚片, 雞蛋/魚糕/黃瓜/香菇]    -    1960
# 55      意式烤飯         [米飯, 洋蔥, 小麥粉, 牛奶, 黃油類]   鍋子    1900
# 56       香草湯                 [甘菊, 洋蔥, 香草奶酪]   鍋子    1900
# 57       炒時蔬                       [油, 包心菜]   煎鍋    1900
# 141     油炸豆腐               [豆腐, 小麥粉, 油/堅果油]   鍋子    1180
# 142   杯裝紅葡萄酒                          [葡萄酒]    -    1160
# 143      比薩餅                  [小麥粉, 蕃茄, 奶酪]   煎鍋    1130
# 144      蛋花湯                       [雞蛋, 洋蔥]   鍋子    1120
# 145      霜淇淋                      [烏雞蛋, 黃油]    -    1120
# 146      蛋糕卷              [小麥粉, 烏雞蛋, 新澤西牛奶]   煎鍋    1120
# 147      栗米湯                   [玉米, 黃油, 牛奶]   鍋子    1120
# 148      雞蛋捲                       [油, 烏雞蛋]   煎鍋    1120
# 149     芝士蛋糕                   [雞蛋, 牛奶, 奶酪]    -    1120
# 150      烤蘑菇                     [油, 香菇/口蘑]    -    1120
# 151      爆米花                           [玉米]   煎鍋    1120
# 152      烤蘋果                       [蘋果, 黃油]    -    1120
# 153    芝士通心粉                     [義大利麵, 奶酪]   鍋子    1120
# 154      烤飯團                        [飯團, 油]    -    1120
# 155      蘑菇飯                   [米飯, 香菇, 口蘑]    -    1120
# 156     牛奶咖啡                      [熱咖啡, 牛奶]   鍋子    1120
# 157      三明治                   [麵包, 黃瓜, 蕃茄]    -    1120
# 158      葡萄醬                          [紫葡萄]   鍋子    1120
# 159      土豆泥                       [土豆, 牛奶]    -    1120
# 160      煎豆腐                    [豆腐, 油, 口蘑]   煎鍋    1120
# 161      玉米粥                       [玉米, 牛奶]   煎鍋    1120
# 162    巧克力香蕉                      [香蕉, 巧克力]    -    1120
# 163   蕃茄芝士火鍋                  [蕃茄, 麵包, 橄欖油]   鍋子    1090
# 164      生魚片              [杜父魚/金槍魚/虹鱒魚/硬頭鱒]    -    1070
# 165      烤年糕                       [年糕, 海苔]   煎鍋    1070
# 166   油炸豆腐壽司                     [米飯, 油炸豆腐]    -    1020
# 167     葡萄麵包                      [麵包, 紫葡萄]    -    1000
# 168    錫紙蘑菇蒸                        [口蘑/香菇]    -    1000
# 169     果醬麵包                      [麵包, 果醬類]    -    1000
# 170    牛油炒蕪菁                       [蕪菁, 黃油]   煎鍋    1000
# 171       炒飯            [米飯, 油, 雞蛋類/香菇/胡蘿蔔]   煎鍋    1000
# 172   法式香煎板魚       [小麥粉, 油, 比目魚/馬蘇鮭魚/鱸魚/鮭魚]    -    1000
# 173       曲奇                  [小麥粉, 雞蛋, 黃油]    -    1000
# 174     炒烏冬麵                       [烏冬麵, 油]    -    1000
# 175    通心粉沙拉                 [義大利麵, 黃瓜, 蕪菁]    -    1000
# 176   番茄芝士沙拉                    [蕃茄, 油, 奶酪]    -    1000
# 177      蛋包飯                [油, 牛奶, 雞蛋, 米飯]   煎鍋    1000
# 178      甜土豆                   [地瓜, 黃油, 雞蛋]    -    1000
# 179   西班牙小油條                  [小麥粉, 油, 烏雞蛋]    -     910
# 180      栗子飯                     [米飯, 栗子罐頭]    -     896
# 181       豆漿                       [大豆, 毛豆]   鍋子     890
# 182      熱咖啡                          [咖啡粉]   鍋子     890
# 183     洋蔥沙拉                           [洋蔥]    -     890
# 184      蘋果醬                           [蘋果]   鍋子     890
# 185     芝士火鍋                      [麵包, 奶酪類]   鍋子     890
# 186     炒蕎麥麵                       [蕎麥麵, 油]    -     890
# 187     香草麵包                [麵包, 甘菊/薄荷/薰衣草]    -     890
# 188     豆奶布丁                       [豆漿, 雞蛋]   鍋子     890
# 189     咖喱肉包                     [小麥粉, 咖喱粉]   煎鍋     890
# 190     現烤蛋糕          [雞蛋, 牛奶, 小麥粉, 黃油, 蜂蜜]          890
# 191      芝士包                     [小麥粉, 奶酪類]   煎鍋     890
# 192   西班牙涼菜湯               [蕃茄, 黃瓜, 洋蔥, 麵包]   鍋子     890
# 193       蛋糕              [小麥粉, 黃油, 雞蛋, 牛奶]    -     890
# 194      牛奶粥                      [米飯, 牛奶類]   鍋子     890
# 195      蒸蛋糕                 [小麥粉, 牛奶, 胡蘿蔔]    -     840
# 196     牛角麵包                       [麵包, 黃油]    -     840
# 197     煎雞蛋捲                    [油, 牛奶, 雞蛋]    -     840
# 198       蛋撻                     [小麥粉, 烏雞蛋]    -     800
# 199      炒河粉        [米粉, 油, 包心菜, 香菇/胡蘿蔔/青椒]    -     784
# 200      煮海苔                           [海苔]   鍋子     780
# 201       布丁                       [牛奶, 雞蛋]   煎鍋     780
# 202     油炸豆腐                        [豆腐, 油]    -     780
# 203       飯團                       [米飯, 海苔]    -     780
# 204     咖喱炒飯                      [米飯, 咖喱粉]   鍋子     780
# 205       煮魚        [暗色頜須鮈/黑魚/銀鯽魚/青花魚/大口鮭魚]   鍋子     780
# 206     咖喱麵包                      [麵包, 咖喱粉]    -     780
# 207    巧克力火鍋                      [巧克力, 麵包]   鍋子     780
# 208       蛋糕                      [小麥粉, 雞蛋]   鍋子     710
# 209      熱牛奶                           [牛奶]   鍋子     670
# 210       烤魚          [香魚/長頜須鮈/馬口魚/黑鰱魚/白鰱魚]    -     670
# 211      烏冬麵                      [小麥粉, 魚糕]    -     670
# 212    草莓大福餅                       [草莓, 年糕]   煎鍋     670
# 213     香草沙拉                  [薄荷, 甘菊, 薰衣草]   鍋子     670
# 214      冷豆腐                       [豆腐, 海苔]    -     670
# 215     蕪菁沙拉                           [蕪菁]    -     670
# 216      蒸麵包                  [小麥粉, 雞蛋, 地瓜]    -     670
# 217      烤茄子                           [茄子]    -     670
# 218      栗子團                         [栗子罐頭]    -     640
# 219     高野豆腐                           [豆腐]   鍋子     560
# 220     蕃茄沙拉                           [蕃茄]    -     560
# 221       豆腐                           [大豆]    -     560
# 222        粥                           [米飯]   鍋子     560
# 223     法式土司                       [麵包, 雞蛋]    -     560
# 224      蛋拌飯                       [米飯, 雞蛋]   煎鍋     560
# 225     義大利麵                       [小麥粉, 油]   鍋子     560
# 226      蕎麥麵                          [蕎麥粉]    -     560
# 227     貢月團子                           [年糕]    -     560
# 228      荷包蛋                        [油, 雞蛋]    -     440
# 229      溫泉蛋                      [烏雞蛋/金雞蛋]    -     440
# 230      草莓醬                           [草莓]   鍋子     440
# 231      烤地瓜                           [地瓜]    -     440
# 232       吐司                       [麵包/白麵包]    -     400
# 233       米飯                            [米]    -     310
# 234       麵包                          [小麥粉]    -     260
# 235      白麵包                           [米粉]    -     260
# 236       腐竹                           [豆漿]    -     260
# 237      煮雞蛋                           [雞蛋]    -     220
# 238       魚糕                   [縱紋鱲/鱸魚/比目魚]    -     220
# 239     烤毒蘑菇                       [油, 毒蘑菇]    -     110
